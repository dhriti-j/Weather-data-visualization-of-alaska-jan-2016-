# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv('weather1.csv')
df.shape
# Out:
# (16743, 14)

# %%
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16743 entries, 0 to 16742
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Data.Precipitation         16743 non-null  float64
#  1   Date.Full                  16743 non-null  object
#  2   Date.Month                 16743 non-null  int64
#  3   Date.Week of               16743 non-null  int64
#  4   Date.Year                  16743 non-null  int64
#  5   Station.City               16743 non-null  object
#  6   Station.Code               16743 non-null  object
#  7   Station.Location           16743 non-null  object
#  8   Station.State              16743 non-null  object
#  9   Data.Temperature.Avg Temp  16743 non-null  int64
#  10  Data.Temperature.Max Temp  16743 non-null  int64
#  11  Data.Temperature.Min Temp  16743 non-null  int64
#  12  Data.Wind.Direction        16743 non-null  int64
# ...

# %%
df["Date.Month"].value_counts()
# Out:
# Date.Month
# 1     1892
# 5     1585
# 10    1585
# 7     1572
# 8     1268
# 12    1268
# 4     1265
# 9     1265
# 3     1262
# 6     1262
# 2     1260
# 11    1259
# Name: count, dtype: int64

# %%
alaska=df[df["Station.State"]=="Alaska"]
alaska
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 4                    0.01  2016-01-03           1             3       2016
# 5                    0.09  2016-01-03           1             3       2016
# 6                    0.05  2016-01-03           1             3       2016
# 7                    0.15  2016-01-03           1             3       2016
# 8                    0.60  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16459                0.00  2017-01-01           1             1       2017
# 16460                0.00  2017-01-01           1             1       2017
# 16461                0.17  2017-01-01           1             1       2017
# 16462                0.00  2017-01-01           1             1       2017
# 16463                1.40  2017-01-01           1             1       2017
#
# ...

# %%
alaska["Date.Month"].value_counts()
# Out:
# Date.Month
# 1     189
# 5     165
# 10    165
# 7     160
# 12    136
# 4     132
# 8     132
# 3     129
# 6     129
# 9     129
# 11    129
# 2     124
# Name: count, dtype: int64

# %%
alaska1= alaska[(alaska["Date.Month"]==1) & (alaska["Date.Year"]==2016)]
alaska1["Date.Full"].value_counts()
# Out:
# Date.Full
# 2016-01-03    31
# 2016-01-10    31
# 2016-01-17    31
# 2016-01-24    31
# 2016-01-31    31
# Name: count, dtype: int64

# %%
alaska1["Station.Code"].value_counts()
# Out:
# Station.Code
# ANC    5
# OTZ    5
# BRW    5
# TAL    5
# TKA    5
# SNP    5
# SGY    5
# SIT    5
# SYA    5
# PTI    5
# PSG    5
# PAQ    5
# ORT    5
# OME    5
# MCG    5
# ADQ    5
# ANN    5
# AKN    5
# KTN    5
# ENA    5
# JNU    5
# ILI    5
# HOM    5
# GKN    5
# FAI    5
# BIG    5
# CDV    5
# CDB    5
# BTT    5
# BET    5
# YAK    5
# Name: count, dtype: int64

# %%
# We have data of 31 codes on all 5 dates of january 2016

# %%
codes =[]
for loc in alaska1["Station.Code"]:
    if loc not in codes:
        codes.append(loc)
codes
# Out:
# ['ANC',
#  'ANN',
#  'BET',
#  'BTT',
#  'CDB',
#  'CDV',
#  'BIG',
#  'FAI',
#  'GKN',
#  'HOM',
#  'ILI',
#  'JNU',
#  'ENA',
#  'KTN',
#  'AKN',
#  'ADQ',
#  'OTZ',
#  'MCG',
#  'OME',
#  'ORT',
#  'PAQ',
#  'PSG',
#  'PTI',
#  'SYA',
#  'SIT',
#  'SGY',
#  'SNP',
#  'TKA',
#  'TAL',
#  'BRW',
#  'YAK']

# %%
x=[]
y=[]
plt.figure(figsize = (20,8))
plot1=plt.scatter(x,y)
overlapping= 0.5
colors = plt.cm.hsv(np.linspace(0, 1,32))
def plotting(code,colour):
    date=alaska1[alaska1["Station.Code"]==code]
    plot1=plt.plot(date["Date.Full"],date["Data.Temperature.Avg Temp"],marker="o", label = code, color=colour,alpha=overlapping)
    plt.legend(fontsize=7, loc="upper right")


for i,loc in enumerate(codes):
    colour= colors[i]
    plotting(loc,colour)
   



plt.xlabel('Dates')
plt.ylabel('Average Temperature(F)')
plt.title('Average Temperature of each station code')
# Out:
# Text(0.5, 1.0, 'Average Temperature of each station code')

# %%
new= {"Code": [],
     "Min": [],
     "Max": [],
     "Avg": []}
new=pd.DataFrame(new)
   
    
for loc in codes:
     alaska_loc = alaska1[alaska1["Station.Code"] == loc]
     
     max_temp= alaska_loc["Data.Temperature.Max Temp"].max()
     min_temp= alaska_loc["Data.Temperature.Min Temp"].min()
     avg_temp=0
     for temp in alaska_loc["Data.Temperature.Avg Temp"]:
       avg_temp= avg_temp + temp
     avg_temp= avg_temp/len(alaska_loc.index)
       
     app= {"Code": loc,
           "Min": min_temp,
           "Max": max_temp,
           "Avg": avg_temp}
     new = new._append(app, ignore_index= True)
new
# Out:
#    Code   Min   Max   Avg
# 0   ANC  19.0  38.0  27.8
# 1   ANN  27.0  46.0  40.6
# 2   BET   4.0  36.0  22.2
# 3   BTT -19.0  32.0   6.8
# 4   CDB  27.0  39.0  32.8
# 5   CDV  22.0  43.0  35.4
# 6   BIG   3.0  39.0  17.4
# 7   FAI -10.0  30.0   4.4
# 8   GKN -14.0  34.0   8.6
# 9   HOM  24.0  42.0  34.4
# 10  ILI  19.0  42.0  32.4
# 11  JNU  22.0  42.0  34.8
# 12  ENA  19.0  37.0  28.6
# 13  KTN  28.0  47.0  39.8
# 14  AKN  18.0  42.0  33.2
# 15  ADQ  30.0  42.0  36.8
# 16  OTZ  -7.0  33.0  15.6
# 17  MCG -12.0  39.0  10.8
# 18  OME  -1.0  32.0  21.2
# 19  ORT -19.0  12.0   0.0
# 20  PAQ  15.0  42.0  28.4
# 21  PSG  60.0  60.0  60.0
# 22  PTI  60.0  60.0  60.0
# 23  SYA  60.0  60.0  60.0
# 24  SIT  33.0  47.0  42.4
# 25  SGY  29.0  42.0  36.2
# 26  SNP  22.0  36.0  30.8
# 27  TKA   8.0  39.0  25.8
# 28  TAL  -6.0  29.0   8.6
# 29  BRW -14.0  16.0   0.8
# 30  YAK  25.0  42.0  35.6

# %%
plt.figure(figsize = (20,8))
plt.plot(new["Code"], new["Min"], color="b", label= 'Min Temp',marker= "o",alpha=overlapping)
plt.plot(new["Code"], new["Max"],color="r", label = "Max Temp",marker= "o",alpha=overlapping)
plt.plot(new["Code"], new["Avg"],color="g", label="Average Temp",marker= "o",alpha=overlapping)
plt.legend()
plt.xlabel('Station Codes')
plt.ylabel('Temperature (F)')
plt.title('Comparison of Temperatures')
# Out:
# Text(0.5, 1.0, 'Comparison of Temperatures')

# %%
alaska_3=alaska1[alaska1["Date.Week of"]==3]
alaska_10=alaska1[alaska1["Date.Week of"]==10]
alaska_17=alaska1[alaska1["Date.Week of"]==17]
alaska_24=alaska1[alaska1["Date.Week of"]==24]
alaska_31=alaska1[alaska1["Date.Week of"]==31]
plt.figure(figsize = (20,8))
colors = plt.cm.hsv(np.linspace(0, 1,6))
plt.bar(alaska_3["Station.Code"],alaska_3["Data.Precipitation"],label="3 jan", color= colors[5])
alaska_3=np.array(alaska_3["Data.Precipitation"])
plt.bar(alaska_10["Station.Code"],alaska_10["Data.Precipitation"],bottom=alaska_3,label="10 jan", color= colors[4])
alaska_10=np.array(alaska_10["Data.Precipitation"])
plt.bar(alaska_17["Station.Code"],alaska_17["Data.Precipitation"],bottom=alaska_3+alaska_10,label="17 jan", color= colors[3])
alaska_17=np.array(alaska_17["Data.Precipitation"])
plt.bar(alaska_24["Station.Code"],alaska_24["Data.Precipitation"],bottom=alaska_17+alaska_10+alaska_3,label="24 jan", color= colors[2])
alaska_24=np.array(alaska_24["Data.Precipitation"])
plt.bar(alaska_31["Station.Code"],alaska_31["Data.Precipitation"],bottom=alaska_24+alaska_17+alaska_10+alaska_3,label="31 jan", color= colors[1])


plt.legend()
plt.xlabel('Station Codes')
plt.ylabel('Precipitation(in inches)')
plt.title('Precipitation in Jan 2016 in Alaska')
# Out:
# Text(0.5, 1.0, 'Precipitation in Jan 2016 in Alaska')
